# %%
# !pip install Faker
# Out:
# Requirement already satisfied: Faker in /usr/local/lib/python3.6/dist-packages (4.1.3)
# Requirement already satisfied: text-unidecode==1.3 in /usr/local/lib/python3.6/dist-packages (from Faker) (1.3)
# Requirement already satisfied: python-dateutil>=2.4 in /usr/local/lib/python3.6/dist-packages (from Faker) (2.8.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil>=2.4->Faker) (1.15.0)

# %%
from collections import namedtuple
from faker import Faker
from collections import defaultdict
from collections import Counter
from functools import reduce
from dateutil.relativedelta import relativedelta
from datetime import date
import time
from functools import wraps
import random

faker = Faker()
user_count = 10_000

Profile = namedtuple("Profile", faker.profile().keys())
Profile.__doc__ = "`named tuple` for fake profile containing various fields providing information about each user's basic details"

for field_ in Profile._fields:
    getattr(Profile,
            field_).__doc__ = f"field `{field_}` containing information for a particular user's {field_} details"
print(help(Profile))


def timer(num):
    """
    Timer decorator that takes a paramter `num` the number of time to run the decorated function and calculate the average
    :param num: int signifying the number of time to run the function
    :return: the decorator for timing `fn` `num` times' average
    """

    def dec(fn):
        """The decorator that uses a closure for calculating average run time"""

        @wraps(fn)
        def inner(*args, **kwargs):
            """the inner most function responsible for carrying out the funtion runs 'num' time and return the average seconds"""
            elapsed = 0
            for i in range(num):
                start = time.perf_counter()
                result = fn(*args, **kwargs)
                end = time.perf_counter()
                elapsed += (end - start)

            print(f"Average time taken to run function {fn} over {num} times = {elapsed / num} seconds")
            return result

        return inner

    return dec


def calculate_metrics_namedtuples(to_print=False, *, fake_profiles: list) -> tuple:
    """
    To use all fake profiles passed by user and do the following:
    1) calculate the highest occurring blood type
    2) mean location
    3) oldest person's age
    4) average age

    :return: Tuple for the tasks' results in same order as above
    """
    blood_groups = []
    current_locations = []
    dobs = []
    for profile in fake_profiles:
        blood_groups.append(profile.blood_group)
        current_locations.append(profile.current_location)
        dobs.append(profile.birthdate)

    today = date.today()

    most_common_blood_group = Counter(blood_groups).most_common(1)[0][0]

    mean_location = reduce(lambda x, y: ((x[0] + y[0]) / 2, (x[1] + y[1]) / 2), current_locations)

    max_age = relativedelta(today, min(dobs))

    avg_age = reduce(lambda x, y: ((x[0] + y[0]) / 2, (x[1] + y[1]) / 2, (x[2] + y[2]) / 2),
                     [(relativedelta(today, x).years, relativedelta(today, x).months, relativedelta(today, x).days) for
                      x in dobs])
    if to_print:
        print(f"Highest occurring blood group= {most_common_blood_group}")
        print(f"Mean location= {mean_location}")
        print(f"Maximum age= {max_age.years}years {max_age.months}months {max_age.days}days")
        print(f"Average age= {avg_age[0]}years {avg_age[1]}months {avg_age[2]}days")

    return most_common_blood_group, mean_location, max_age, avg_age


def calculate_metrics_dictionary(to_print=False, *, fake_profiles: list) -> tuple:
    """
    1) calculate the highest occurring blood type
    2) mean location
    3) oldest person's age
    4) average age

    :return: Tuple for the tasks' results in same order as above
    """
    record_dict = defaultdict(dict)
    for profile in fake_profiles:
        record_dict[profile['ssn']] = profile

    most_common_blood_group = Counter([b['blood_group'] for a, b in record_dict.items()]).most_common(1)[0][0]

    mean_location = reduce(lambda x, y: ((x[0] + y[0]) / 2, (x[1] + y[1]) / 2),
                           [b['current_location'] for a, b in record_dict.items()])

    today = date.today()
    max_age = relativedelta(today, min([b['birthdate'] for a, b in record_dict.items()]))

    avg_age = reduce(lambda x, y: ((x[0] + y[0]) / 2, (x[1] + y[1]) / 2, (x[2] + y[2]) / 2), [(relativedelta(today, b[
        'birthdate']).years, relativedelta(today, b['birthdate']).months, relativedelta(today, b['birthdate']).days) for
                                                                                              a, b in
                                                                                              record_dict.items()])
    if to_print:
        print(f"Highest occurring blood group= {most_common_blood_group}")
        print(f"Mean location= {mean_location}")
        print(f"Maximum age= {max_age.years}years {max_age.months}months {max_age.days}days")
        print(f"Average age= {avg_age[0]}years {avg_age[1]}months {avg_age[2]}days")

    return most_common_blood_group, mean_location, max_age, avg_age


def get_profiles_namedtuples():
    """
    To use namedtuples and Faker library to generate 10000 random user profiles
    """
    all_profiles = []
    for _ in range(user_count):
        all_profiles.append(Profile(**faker.profile()))

    return all_profiles


def get_profiles_dictionary():
    """
    To use dictionary and Faker library to generate 10000 random user profiles
    """
    all_profiles = []
    for _ in range(user_count):
        fake = faker.profile()
        all_profiles.append(fake)
    return all_profiles


@timer(num=100)
def run_task_namedtuple_metrics():
    """Calls calculate_metrics_namedtuples() feeding profiles from get_profiles_namedtuples() using the decorator `timer` """
    calculate_metrics_namedtuples(fake_profiles=get_profiles_namedtuples())


@timer(num=100)
def run_task_dictionary_metrics():
    """Calls calculate_metrics_dictionary() feeding profiles from get_profiles_dictionary() which returns a dictionary of profiles the decorator `timer` """
    calculate_metrics_dictionary(fake_profiles=get_profiles_dictionary())
# Out:
# Help on class Profile in module __main__:
#
# class Profile(builtins.tuple)
#  |  `named tuple` for fake profile containing various fields providing information about each user's basic details
#  |
#  |  Method resolution order:
#  |      Profile
#  |      builtins.tuple
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __getnewargs__(self)
#  |      Return self as a plain tuple.  Used by copy and pickle.
#  |
#  |  __repr__(self)
#  |      Return a nicely formatted representation string
#  |
#  |  _asdict(self)
#  |      Return a new OrderedDict which maps field names to their values.
#  |
#  |  _replace(_self, **kwds)
#  |      Return a new Profile object replacing specified fields with new values
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods defined here:
#  |
#  |  _make(iterable, new=<built-in method __new__ of type object at 0x9d43a0>, len=<built-in function len>) from builtins.type
#  |      Make a new Profile object from a sequence or iterable
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(_cls, job, company, ssn, residence, current_location, blood_group, website, username, name, sex, address, mail, birthdate)
#  |      Create new instance of Profile(job, company, ssn, residence, current_location, blood_group, website, username, name, sex, address, mail, birthdate)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  job
#  |      field `job` containing information for a particular user's job details
#  |
#  |  company
#  |      field `company` containing information for a particular user's company details
#  |
#  |  ssn
#  |      field `ssn` containing information for a particular user's ssn details
#  |
#  |  residence
#  |      field `residence` containing information for a particular user's residence details
#  |
#  |  current_location
#  |      field `current_location` containing information for a particular user's current_location details
#  |
#  |  blood_group
#  |      field `blood_group` containing information for a particular user's blood_group details
#  |
#  |  website
#  |      field `website` containing information for a particular user's website details
#  |
#  |  username
#  |      field `username` containing information for a particular user's username details
#  |
#  |  name
#  |      field `name` containing information for a particular user's name details
#  |
#  |  sex
#  |      field `sex` containing information for a particular user's sex details
#  |
#  |  address
#  |      field `address` containing information for a particular user's address details
#  |
#  |  mail
#  |      field `mail` containing information for a particular user's mail details
#  |
#  |  birthdate
#  |      field `birthdate` containing information for a particular user's birthdate details
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  _fields = ('job', 'company', 'ssn', 'residence', 'current_location', '...
#  |
#  |  _source = "from builtins import property as _property, tupl...temgette...
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from builtins.tuple:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, key, /)
#  |      Return self[key].
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __hash__(self, /)
#  |      Return hash(self).
#  |
#  |  __iter__(self, /)
#  |      Implement iter(self).
#  |
#  |  __le__(self, value, /)
#  |      Return self<=value.
#  |
#  |  __len__(self, /)
#  |      Return len(self).
#  |
#  |  __lt__(self, value, /)
#  |      Return self<value.
#  |
#  |  __mul__(self, value, /)
#  |      Return self*value.
#  |
#  |  __ne__(self, value, /)
#  |      Return self!=value.
#  |
#  |  __rmul__(self, value, /)
#  |      Return value*self.
#  |
#  |  count(...)
#  |      T.count(value) -> integer -- return number of occurrences of value
#  |
#  |  index(...)
#  |      T.index(value, [start, [stop]]) -> integer -- return first index of value.
#  |      Raises ValueError if the value is not present.
#
# None

# %%
print(run_task_namedtuple_metrics())
print(run_task_dictionary_metrics())
# Out:
# Average time taken to run function <function run_task_namedtuple_metrics at 0x7f7a060c2730> over 100 times = 22.84001329167001 seconds
# None
# Average time taken to run function <function run_task_dictionary_metrics at 0x7f7a060c2950> over 100 times = 23.20322694580003 seconds
# None

# %%
def get_capitalized_letters(string):
    """Returns joined string if characters are upper case"""
    return ''.join(x for x in string if x.isupper())

# %%
def stock_market():
    """
    To create a fake stock data set for imaginary stock exchange for top 100 companies (name, symbol, open, high, close).
    Tasks_ToDo: Assign a random weight to all the companies. Calculate and show what value stock market started at, what was the highest value during the day and where did it end.
    """
    all_companies = []
    Stocks = namedtuple("Stocks", 'name symbol open high close company_weight')
    for _ in range(100):
        name = faker.company()
        open_ = round(random.uniform(41, 3999), 2)
        high_num = round(random.uniform(0.613, 1.4), 2)  # market is damn volatile
        high = open_ * high_num if high_num > 1.0 else open_
        close = random.uniform(open_ - random.randint(-10, 10), high + random.randint(-8, 10))
        if close > high:
            high = close

        all_companies.append(
            Stocks(name=name, symbol=get_capitalized_letters(name), open=open_, high=round(high, 2),
                   close=round(close, 2),
                   company_weight=round(random.uniform(15, 80), 3)))

    stock_index = round(sum(x.open * x.company_weight for x in all_companies), 4)
    highest_for_day = round(max(x.high * x.company_weight for x in all_companies), 2)
    lowest_close_for_day = round(min(x.close * x.company_weight for x in all_companies), 2)

    print(f"\n------------------------------------Top 100 listed companies on TSAI Stock Exchange------------------------------------\n")
    [print(x) for x in sorted(all_companies, key=lambda x:x.symbol)]
    print(f"\n\n--------------Main details on {date.today()}--------------")
    print(f"\nStock Index: {stock_index}")
    print(f"Highest for the day: {highest_for_day}")
    print(f"Lowest close for the day: {lowest_close_for_day}")

# %%
stock_market()
# Out:
# ------------------------------------Top 100 listed companies on TSAI Stock Exchange------------------------------------
#
# Stocks(name='Adams, Carter and Roach', symbol='ACR', open=701.17, high=701.23, close=701.23, company_weight=54.377)
# Stocks(name='Allen Inc', symbol='AI', open=1289.07, high=1469.54, close=1323.67, company_weight=71.532)
# Stocks(name='Austin-Marquez', symbol='AM', open=970.25, high=973.14, close=973.14, company_weight=30.35)
# Stocks(name='Avery-Reilly', symbol='AR', open=1023.03, high=1094.64, close=1039.1, company_weight=63.819)
# Stocks(name='Beck-Baker', symbol='BB', open=3504.26, high=3506.0, close=3506.0, company_weight=53.821)
# Stocks(name='Berry-Baker', symbol='BB', open=2794.93, high=3493.66, close=2977.08, company_weight=39.262)
# Stocks(name='Baker, Douglas and Ramos', symbol='BDR', open=906.34, high=907.7, close=907.7, company_weight=73.298)
# Stocks(name='Browning, Hernandez and Rice', symbol='BHR', open=771.54, high=776.04, close=776.04, company_weight=68.071)
# Stocks(name='Ball Inc', symbol='BI', open=1820.05, high=1820.05, close=1815.37, company_weight=43.555)
# Stocks(name='Buchanan Ltd', symbol='BL', open=3600.13, high=3603.36, close=3603.36, company_weight=20.458)
# Stocks(name='Brooks, Martin and May', symbol='BMM', open=2152.23, high=2152.23, close=2143.72, company_weight=64.617)
# Stocks(name='Blankenship-Ramirez', symbol='BR', open=863.88, high=1200.79, close=1061.92, company_weight=31.365)
# Stocks(name='Bates-Sellers', symbol='BS', open=867.99, high=867.99, close=864.88, company_weight=73.7)
# Stocks(name='Brown-Stewart', symbol='BS', open=959.18, high=1112.65, close=1049.59, company_weight=37.338)
# Stocks(name='Butler-Wright', symbol='BW', open=2814.52, high=2819.81, close=2819.81, company_weight=44.678)
# Stocks(name='Blackburn-Williams', symbol='BW', open=524.14, high=533.05, close=533.05, company_weight=67.187)
# Stocks(name='Cole Group', symbol='CG', open=50.32, high=57.56, close=57.56, company_weight=44.797)
# Stocks(name='Campbell-Harris', symbol='CH', open=3154.65, high=4353.42, close=3520.12, company_weight=58.156)
# Stocks(name='Carrillo, Hampton and Joyce', symbol='CHJ', open=213.15, high=217.03, close=217.03, company_weight=24.342)
# Stocks(name='Cox, Larson and Bauer', symbol='CLB', open=3301.69, high=3532.81, close=3379.23, company_weight=30.151)
# Stocks(name='Cruz LLC', symbol='CLLC', open=3727.1, high=3727.1, close=3719.69, company_weight=56.14)
# Stocks(name='Campbell, Pena and Maynard', symbol='CPM', open=2052.56, high=2058.58, close=2058.58, company_weight=18.594)
# Stocks(name='Cox-Stanley', symbol='CS', open=3298.19, high=3298.19, close=3297.76, company_weight=47.953)
# Stocks(name='Davis-Andersen', symbol='DA', open=1337.2, high=1337.67, close=1337.67, company_weight=44.011)
# Stocks(name='Davis-Jones', symbol='DJ', open=3590.83, high=3626.74, close=3599.94, company_weight=51.166)
# Stocks(name='Donovan PLC', symbol='DPLC', open=2759.87, high=2759.87, close=2758.5, company_weight=54.891)
# Stocks(name='Duffy, Thompson and Romero', symbol='DTR', open=1766.38, high=2437.6, close=2167.04, company_weight=34.369)
# Stocks(name='Elliott, Roman and Martinez', symbol='ERM', open=520.32, high=598.37, close=591.6, company_weight=23.941)
# Stocks(name='Flores-Dorsey', symbol='FD', open=2515.54, high=2515.54, close=2506.55, company_weight=44.641)
# Stocks(name='Fisher, Harmon and Walker', symbol='FHW', open=3145.72, high=3554.66, close=3356.8, company_weight=78.961)
# Stocks(name='Franklin, Martinez and Barajas', symbol='FMB', open=1485.0, high=1485.35, close=1485.35, company_weight=72.278)
# Stocks(name='Figueroa, Sullivan and Lopez', symbol='FSL', open=3595.07, high=4997.15, close=4183.2, company_weight=48.953)
# Stocks(name='Graham, Brown and Strong', symbol='GBS', open=1519.03, high=1519.63, close=1519.63, company_weight=68.05)
# Stocks(name='Garcia-Mclaughlin', symbol='GM', open=1103.82, high=1116.18, close=1116.18, company_weight=36.593)
# Stocks(name='Gibbs, Moreno and Johnson', symbol='GMJ', open=1087.22, high=1096.19, close=1096.19, company_weight=73.319)
# Stocks(name='Galvan-Phillips', symbol='GP', open=248.41, high=340.32, close=327.07, company_weight=15.174)
# Stocks(name='Gomez PLC', symbol='GPLC', open=1155.23, high=1159.25, close=1159.25, company_weight=55.298)
# Stocks(name='Guzman PLC', symbol='GPLC', open=2136.63, high=2798.99, close=2639.76, company_weight=50.856)
# Stocks(name='Garcia-Smith', symbol='GS', open=1918.44, high=1918.44, close=1915.99, company_weight=34.107)
# Stocks(name='Hernandez, Franklin and Hicks', symbol='HFH', open=1166.05, high=1166.05, close=1159.62, company_weight=38.267)
# Stocks(name='Hill Group', symbol='HG', open=1267.38, high=1710.96, close=1700.0, company_weight=74.947)
# Stocks(name='Hunt-Harrison', symbol='HH', open=534.09, high=678.29, close=563.4, company_weight=62.597)
# Stocks(name='Harrison LLC', symbol='HLLC', open=1486.28, high=1605.18, close=1593.84, company_weight=56.82)
# Stocks(name='Holder, Mcgee and Rodriguez', symbol='HMR', open=1441.58, high=1450.35, close=1450.35, company_weight=30.992)
# Stocks(name='Haynes, Peters and Jackson', symbol='HPJ', open=261.2, high=300.38, close=291.26, company_weight=57.625)
# Stocks(name='Harmon PLC', symbol='HPLC', open=2950.22, high=3038.73, close=2972.13, company_weight=29.969)
# Stocks(name='Hester-Ramirez', symbol='HR', open=216.01, high=222.49, close=221.36, company_weight=63.355)
# Stocks(name='Harrison, Webb and Mcdonald', symbol='HWM', open=245.76, high=251.45, close=251.45, company_weight=57.957)
# Stocks(name='Jones, Collins and Barker', symbol='JCB', open=1075.73, high=1081.22, close=1081.22, company_weight=17.014)
# Stocks(name='Jackson Group', symbol='JG', open=2707.79, high=3168.11, close=2796.93, company_weight=62.41)
# Stocks(name='Lee, Jones and Johnson', symbol='LJJ', open=287.85, high=287.85, close=280.54, company_weight=46.36)
# Stocks(name='Lopez, Mora and Smith', symbol='LMS', open=767.61, high=859.72, close=812.14, company_weight=23.21)
# Stocks(name='Lopez, Ramirez and Lee', symbol='LRL', open=3721.55, high=5061.31, close=4906.78, company_weight=19.727)
# Stocks(name='Mosley, Brooks and Greer', symbol='MBG', open=474.5, high=540.93, close=483.74, company_weight=33.562)
# Stocks(name='Mendoza Group', symbol='MG', open=3412.95, high=3856.63, close=3772.52, company_weight=79.185)
# Stocks(name='Murray Group', symbol='MG', open=2283.77, high=2923.23, close=2792.13, company_weight=49.293)
# Stocks(name='Miller, Gibbs and Miller', symbol='MGM', open=2073.26, high=2080.99, close=2080.99, company_weight=67.33)
# Stocks(name='Mason, Hunter and Neal', symbol='MHN', open=2260.2, high=3051.27, close=2387.69, company_weight=54.922)
# Stocks(name='Marks LLC', symbol='MLLC', open=2480.26, high=2480.26, close=2475.97, company_weight=76.865)
# Stocks(name='Mcdonald-Miller', symbol='MM', open=1531.21, high=1975.26, close=1930.99, company_weight=16.023)
# Stocks(name='Moore, Phillips and Ortiz', symbol='MPO', open=1601.77, high=1842.04, close=1650.87, company_weight=44.636)
# Stocks(name='Murphy-Shelton', symbol='MS', open=151.17, high=155.81, close=155.81, company_weight=25.857)
# Stocks(name='Martinez-Shelton', symbol='MS', open=2641.77, high=3619.22, close=2919.41, company_weight=33.871)
# Stocks(name='Miranda, Smith and Romero', symbol='MSR', open=1977.97, high=2215.33, close=2077.63, company_weight=71.953)
# Stocks(name='Moore, Wolfe and Campbell', symbol='MWC', open=3719.83, high=4872.98, close=4103.25, company_weight=27.065)
# Stocks(name='Nolan Group', symbol='NG', open=1112.27, high=1112.27, close=1106.86, company_weight=22.354)
# Stocks(name='Nelson LLC', symbol='NLLC', open=3557.12, high=3557.12, close=3557.02, company_weight=16.797)
# Stocks(name='Nolan, Trujillo and Barber', symbol='NTB', open=2836.04, high=2843.73, close=2843.73, company_weight=34.266)
# Stocks(name='Paul, Butler and Taylor', symbol='PBT', open=1207.11, high=1665.81, close=1415.55, company_weight=37.056)
# Stocks(name='Phillips, Ellison and Lee', symbol='PEL', open=1519.86, high=1580.65, close=1571.67, company_weight=70.727)
# Stocks(name='Peters Group', symbol='PG', open=1462.4, high=1462.4, close=1453.59, company_weight=24.803)
# Stocks(name='Peterson-Pruitt', symbol='PP', open=3035.37, high=3612.09, close=3112.69, company_weight=38.303)
# Stocks(name='Phillips PLC', symbol='PPLC', open=1730.48, high=1747.78, close=1741.04, company_weight=76.077)
# Stocks(name='Randall-Brown', symbol='RB', open=1774.74, high=2271.67, close=1868.51, company_weight=79.68)
# Stocks(name='Rasmussen, Henry and Pierce', symbol='RHP', open=1745.94, high=2444.32, close=2439.91, company_weight=59.224)
# Stocks(name='Robinson, Jacobson and Jimenez', symbol='RJJ', open=2218.52, high=2218.52, close=2208.84, company_weight=52.329)
# Stocks(name='Roberts, Johnson and Ross', symbol='RJR', open=2960.88, high=3789.93, close=2995.62, company_weight=19.18)
# Stocks(name='Rogers Ltd', symbol='RL', open=128.24, high=151.32, close=150.16, company_weight=49.251)
# Stocks(name='Rowe LLC', symbol='RLLC', open=1377.81, high=1380.81, close=1380.81, company_weight=30.362)
# Stocks(name='Ray and Sons', symbol='RS', open=3534.36, high=3535.46, close=3535.46, company_weight=73.358)
# Stocks(name='Ruiz, Thornton and Santiago', symbol='RTS', open=274.96, high=279.07, close=279.07, company_weight=22.189)
# Stocks(name='Santiago, Brown and Cross', symbol='SBC', open=2881.67, high=2881.67, close=2873.93, company_weight=22.514)
# Stocks(name='Sweeney-Ford', symbol='SF', open=1842.21, high=2450.14, close=2178.55, company_weight=58.725)
# Stocks(name='Smith-Hart', symbol='SH', open=2959.83, high=2964.51, close=2964.51, company_weight=68.659)
# Stocks(name='Steele Ltd', symbol='SL', open=2665.54, high=2669.23, close=2669.23, company_weight=75.768)
# Stocks(name='Summers, Pugh and Hopkins', symbol='SPH', open=876.47, high=1148.18, close=1136.54, company_weight=15.457)
# Stocks(name='Sparks, Smith and Taylor', symbol='SST', open=2028.38, high=2037.23, close=2037.23, company_weight=70.479)
# Stocks(name='Taylor-Davis', symbol='TD', open=3663.34, high=3669.13, close=3669.13, company_weight=47.469)
# Stocks(name='Vega-Mcgrath', symbol='VM', open=905.58, high=922.07, close=922.07, company_weight=68.936)
# Stocks(name='Welch, Baird and Swanson', symbol='WBS', open=3926.3, high=4397.46, close=4291.16, company_weight=23.369)
# Stocks(name='Williams-Garcia', symbol='WG', open=3466.02, high=4436.51, close=3746.94, company_weight=28.336)
# Stocks(name='Washington Group', symbol='WG', open=1256.11, high=1256.11, close=1253.42, company_weight=70.11)
# Stocks(name='Wallace Group', symbol='WG', open=1260.98, high=1487.96, close=1417.57, company_weight=18.084)
# Stocks(name='Wilson, Gordon and Garcia', symbol='WGG', open=3535.48, high=3535.48, close=3535.41, company_weight=17.687)
# Stocks(name='Wood Ltd', symbol='WL', open=2301.51, high=2301.51, close=2301.32, company_weight=60.683)
# Stocks(name='Wall Ltd', symbol='WL', open=1633.78, high=1699.13, close=1697.13, company_weight=37.187)
# Stocks(name='White LLC', symbol='WLLC', open=325.56, high=332.14, close=332.14, company_weight=53.267)
# Stocks(name='Williams and Sons', symbol='WS', open=3145.66, high=3365.86, close=3171.77, company_weight=42.803)
# Stocks(name='Williams, Schwartz and Howell', symbol='WSH', open=2225.65, high=2693.04, close=2432.16, company_weight=17.901)
# Stocks(name='Webb, Turner and Bowman', symbol='WTB', open=1945.92, high=2432.4, close=2047.2, company_weight=23.635)
#
#
# --------------Main details on 2020-09-30--------------
#
# Stock Index: 8627759.0991
# Highest for the day: 305387.25
# Lowest close for the day: 2578.52
